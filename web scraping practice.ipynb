# %%
# data-id  ka use web scrapping me nahi kar sakte

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
a = requests.get('https://www.flipkart.com/clothing-and-accessories/winter-wear/pr?sid=clo%2Cqvw&otracker=categorytree&p%5B%5D=facets.ideal_for%255B%255D%3DMen&otracker=nmenu_sub_Men_0_Winter%20Wear')
a
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(a.content,'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim2.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css" rel="stylesheet"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.615ed9.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https:///www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Flipkart.com" name="og_site_name" property="og:site_name"/>
# ...

# %%
product = soup.find_all("div",class_="_1xHGtK _373qXS")
# product

# %%
# product Name 
product_name=[]
selling_price=[]
actual_price=[]
discount=[]
size = []    
for this in product:
    P_N=(this.find("a",class_="IRpwTa").text)
    S_P = (this.find("div",class_="_30jeq3").text)
    A_P = this.find("div",class_="_3I9_wc").text
    Ds= this.find("div",class_="_3Ay6Sb").text
#     Sz=this.find("div",class_="_376u-U").text
#     size can not be fatch 
    
    product_name.append(P_N if P_N else "NULL")
    selling_price.append(S_P if S_P else "NULL")
    actual_price.append(A_P if A_P else "NULL")
    discount.append(Ds if Ds else "NULL" )
    size.append(Sz if Sz else "NULL")
    
print(product_name)
print(len(product_name))
print(selling_price)
print(len(selling_price))
print(actual_price)
print(len(actual_price))
# len(product_name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[89], line 12
#      10 A_P = this.find("div",class_="_3I9_wc").text
#      11 Ds= this.find("div",class_="_3Ay6Sb").text
# ---> 12 Sz=this.find("div",class_="_376u-U").text
#      14 product_name.append(P_N if P_N else "NULL")
#      15 selling_price.append(S_P if S_P else "NULL")
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
print(discount)
print(len(discount))
# Out:
# ['70% off', '70% off', '86% off', '78% off', '66% off', '85% off', '75% off', '80% off', '60% off', '81% off', '75% off', '57% off', '68% off', '70% off', '71% off', '80% off', '70% off', '80% off', '66% off', '50% off', '75% off', '80% off', '78% off', '75% off', '78% off', '83% off', '75% off', '80% off', '75% off', '70% off', '75% off', '80% off', '83% off', '66% off', '70% off', '39% off', '70% off', '46% off', '83% off', '68% off']
# 40

# %%
#    selling price
rat = soup.find_all("div",{"class":"_30jeq3"})
cnt=0
selling_price=[]
for i in rat:
    cnt+=1
#     print(i.string)
    selling_price.append(i.text) if i else "null"
    
    
print(cnt)
print(selling_price)
len(selling_price)
# Out:
# 40
# ['₹594', '₹599', '₹130', '₹150', '₹499', '₹149', '₹349', '₹599', '₹1,799', '₹128', '₹499', '₹399', '₹409', '₹299', '₹499', '₹299', '₹499', '₹259', '₹367', '₹1,251', '₹425', '₹389', '₹499', '₹296', '₹322', '₹489', '₹599', '₹349', '₹322', '₹294', '₹399', '₹439', '₹148', '₹499', '₹322', '₹890', '₹399', '₹499', '₹409', '₹739']
# 40

# %%
#   actual prices
rat = soup.find_all("div",{"class":"_3I9_wc"})
cnt=0
actual_price=[]
for i in rat:
    cnt+=1
#     print(i.string)
    actual_price.append(i.text if i else "null") 
    
    
print(cnt)
print(actual_price)
len(actual_price)
# Out:
# 39
# ['₹1,999', '₹1,999', '₹999', '₹699', '₹1,499', '₹999', '₹1,199', '₹1,999', '₹699', '₹1,999', '₹1,599', '₹1,299', '₹999', '₹2,499', '₹1,399', '₹2,499', '₹2,999', '₹1,299', '₹2,999', '₹999', '₹1,999', '₹1,999', '₹1,399', '₹1,999', '₹1,999', '₹1,999', '₹1,199', '₹1,999', '₹999', '₹1,599', '₹1,499', '₹499', '₹1,499', '₹1,999', '₹1,799', '₹1,599', '₹2,499', '₹1,299', '₹1,000']
# 39

# %%
al_info = soup.find_all('div',class_='_2B099V')

# %%
len(al_info)

# %%
# class="IRpwTa"
name =[]
price=[]
real_price=[]
Discount=[]

for i in al_info:
    x=i.find('a',class_="IRpwTa").text
    y=i.find('div',class_="_30jeq3").text
    z=i.find('div',class_="_3I9_wc").text
    p=i.find('div',class_="_3Ay6Sb").text


    name.append(x)
    price.append(y)
    real_price.append(z)
    Discount.append(p)

    

#     print(x)

print("total name",len(name))
print("total prices",len(price))
print("total real_price",len(real_price))

# %%
size=[]
for i in al_info:
    x = i.find('div', {'class': ['rcweVK', '_376u-U']}).text
#     size.append(x)
    x
# print(Discount)
# len(Discount)

# %%
sizee= soup.find("div",class_="_376u-U")
print(sizee)
# Out:
# None

# %%
product = soup.find_all("div", {"class": "_1xHGtK _373qXS"})
# print(product.prettify())
# product.find(class_="IRpwTa")

# %%
product_name=[]
count=0
for this in product:
    count+=1
#     print(count)
#     print(this.find(class_="IRpwTa").text)
    product_name.append(this.find("a",class_="IRpwTa").text)
    
print(product_name)
len(product_name)
# Out:
#   Cell In[62], line 7
#     product_name.append(this.find("span",class_=""_376u-U").text)
#                                                         ^
# SyntaxError: unterminated string literal (detected at line 7)

# %%
# Out:
# []

# %%
# r = requests.get("https://www.olx.in/jaipur_g4059123/bikes_c2198/")
# r

# %%
 from bs4 import BeautifulSoup

# Replace this with your HTML content or scraping code
html_content = """
<div>
    <span class="_376u-U">Size</span> ==$0
    "&nbsp;"
    <!-- Sizes are hidden within this comment -->
    <!-- S,M,L,XL,XXL -->
</div>
"""

# Parse HTML content
soup = BeautifulSoup(html_content, 'html.parser')

# Find div containing size information
product = soup.find("div")

if product:
    # Extract comments within the div
    comments = product.find_all(string=lambda text: isinstance(text, Comment))

    # Extract sizes from comments
    sizes = []
    for comment in comments:
        if "Sizes are hidden within this comment" in str(comment):
            sizes_text = str(comment).split('--')[1].strip()
            sizes = sizes_text.split(',')

    print("Sizes:", sizes)
else:
    print("No size information found in the provided HTML")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[90], line 21
#      17 product = soup.find("div")
#      19 if product:
#      20    # Extract comments within the div
# ---> 21    comments = product.find_all(string=lambda text: isinstance(text, Comment))
#      23    # Extract sizes from comments
#      24    sizes = []
#
# File ~\anaconda3\lib\site-packages\bs4\element.py:1892, in Tag.find_all(self, name, attrs, recursive, string, limit, **kwargs)
#    1890 if not recursive:
#    1891     generator = self.children
# -> 1892 return self._find_all(name, attrs, string, limit, generator, **kwargs)
#
# File ~\anaconda3\lib\site-packages\bs4\element.py:827, in PageElement._find_all(self, name, attrs, string, limit, generator, **kwargs)
#     825     break
#     826 if i:
# --> 827     found = strainer.search(i)
#     828     if found:
#     829         results.append(found)
# ...
